# %%
import pandas as pd
# Specify the file path
file_path = "E:\Project_2\Bird_Monitoring_Data_GRASSLAND.XLSX"

# Read the Excel file with multiple sheets
excel_data = pd.ExcelFile(file_path)

# Get all sheet names
sheet_names = excel_data.sheet_names

# Read data from all sheets into a dictionary
sheets_dict = {sheet: excel_data.parse(sheet) for sheet in sheet_names}
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\P'
# <>:3: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\Gowtham\AppData\Local\Temp\ipykernel_26228\2337013175.py:3: SyntaxWarning: invalid escape sequence '\P'
#   file_path = "E:\Project_2\Bird_Monitoring_Data_GRASSLAND.XLSX"

# %%
# Example: Convert sheets_dict to a single DataFrame; this will add a new sheet column at the last.
combined_df = pd.concat(
    [df.assign(Sheet=sheet_name) for sheet_name, df in sheets_dict.items()],
    ignore_index=True
)
# Out:
# C:\Users\Gowtham\AppData\Local\Temp\ipykernel_26228\3173835141.py:2: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined_df = pd.concat(

# %%
# later u can Drop the 'Sheet' column
combined_df = combined_df.drop(columns=['Sheet'])

# %%
combined_df
# Out:
#      Admin_Unit_Code Sub_Unit_Code  Plot_Name Location_Type  Year       Date  \
# 0               ANTI           NaN  ANTI-0054     Grassland  2018 2018-05-22
# 1               ANTI           NaN  ANTI-0054     Grassland  2018 2018-05-22
# 2               ANTI           NaN  ANTI-0054     Grassland  2018 2018-05-22
# 3               ANTI           NaN  ANTI-0054     Grassland  2018 2018-05-22
# 4               ANTI           NaN  ANTI-0054     Grassland  2018 2018-05-22
# ...              ...           ...        ...           ...   ...        ...
# 8526            MONO           NaN  MONO-0089     Grassland  2018 2018-05-10
# 8527            MONO           NaN  MONO-0089     Grassland  2018 2018-05-10
# 8528            MONO           NaN  MONO-0089     Grassland  2018 2018-05-10
# 8529            MONO           NaN  MONO-0089     Grassland  2018 2018-05-10
# 8530            MONO           NaN  MONO-0089     Grassland  2018 2018-05-10
#
#      Start_Time  End_Time          Observer Visit  ... AOU_Code  \
# 0      05:35:00  05:45:00  Elizabeth Oswald     1  ...     CHSP
# 1      05:35:00  05:45:00  Elizabeth Oswald     1  ...     EABL
# 2      05:35:00  05:45:00  Elizabeth Oswald     1  ...     GRSP
# 3      05:35:00  05:45:00  Elizabeth Oswald     1  ...     EABL
# 4      05:35:00  05:45:00  Elizabeth Oswald     1  ...     FISP
# ...         ...       ...               ...   ...  ...      ...
# 8526   06:35:00  06:46:00    Brian Swimelar     1  ...     EUST
# 8527   06:35:00  06:46:00    Brian Swimelar     1  ...     EUST
# 8528   06:35:00  06:46:00    Brian Swimelar     1  ...     EUST
# 8529   06:35:00  06:46:00    Brian Swimelar     1  ...     EUST
# 8530   06:35:00  06:46:00    Brian Swimelar     1  ...     EUST
#
#      PIF_Watchlist_Status Regional_Stewardship_Status Temperature Humidity  \
# 0                   False                       False        20.0     79.0
# 1                   False                       False        20.0     79.0
# 2                   False                       False        20.0     79.0
# 3                   False                       False        20.0     79.0
# 4                   False                        True        20.0     79.0
# ...                   ...                         ...         ...      ...
# 8526                False                       False        19.0     63.0
# 8527                False                       False        19.0     63.0
# 8528                False                       False        19.0     63.0
# 8529                False                       False        19.0     63.0
# 8530                False                       False        19.0     63.0
#
#                   Sky                                       Wind  \
# 0     Cloudy/Overcast   Light breeze (4-7 mph) wind felt on face
# 1     Cloudy/Overcast   Light breeze (4-7 mph) wind felt on face
# 2     Cloudy/Overcast   Light breeze (4-7 mph) wind felt on face
# 3     Cloudy/Overcast   Light breeze (4-7 mph) wind felt on face
# 4     Cloudy/Overcast   Light breeze (4-7 mph) wind felt on face
# ...               ...                                        ...
# 8526    Partly Cloudy  Light air movement (1-3 mph) smoke drifts
# 8527    Partly Cloudy  Light air movement (1-3 mph) smoke drifts
# 8528    Partly Cloudy  Light air movement (1-3 mph) smoke drifts
# 8529    Partly Cloudy  Light air movement (1-3 mph) smoke drifts
# 8530    Partly Cloudy  Light air movement (1-3 mph) smoke drifts
#
#                  Disturbance  Previously_Obs Initial_Three_Min_Cnt
# 0     Slight effect on count           False                  True
# 1     Slight effect on count           False                 False
# 2     Slight effect on count           False                  True
# 3     Slight effect on count           False                  True
# 4     Slight effect on count           False                  True
# ...                      ...             ...                   ...
# 8526  Slight effect on count           False                 False
# 8527  Slight effect on count           False                 False
# 8528  Slight effect on count           False                 False
# 8529  Slight effect on count           False                 False
# 8530  Slight effect on count           False                 False
#
# [8531 rows x 29 columns]

# %%
combined_df.count()
# Out:
# Admin_Unit_Code                8531
# Sub_Unit_Code                     0
# Plot_Name                      8531
# Location_Type                  8531
# Year                           8531
# Date                           8531
# Start_Time                     8531
# End_Time                       8531
# Observer                       8531
# Visit                          8531
# Interval_Length                8531
# ID_Method                      8530
# Distance                       7137
# Flyover_Observed               8531
# Sex                            8531
# Common_Name                    8531
# Scientific_Name                8531
# AcceptedTSN                    8507
# TaxonCode                      8529
# AOU_Code                       8531
# PIF_Watchlist_Status           8531
# Regional_Stewardship_Status    8531
# Temperature                    8531
# Humidity                       8531
# Sky                            8531
# Wind                           8531
# Disturbance                    8531
# Previously_Obs                 8531
# Initial_Three_Min_Cnt          8531
# dtype: int64

# %%
combined_df.isna().sum()
# Out:
# Admin_Unit_Code                   0
# Sub_Unit_Code                  8531
# Plot_Name                         0
# Location_Type                     0
# Year                              0
# Date                              0
# Start_Time                        0
# End_Time                          0
# Observer                          0
# Visit                             0
# Interval_Length                   0
# ID_Method                         1
# Distance                       1394
# Flyover_Observed                  0
# Sex                               0
# Common_Name                       0
# Scientific_Name                   0
# AcceptedTSN                      24
# TaxonCode                         2
# AOU_Code                          0
# PIF_Watchlist_Status              0
# Regional_Stewardship_Status       0
# Temperature                       0
# Humidity                          0
# Sky                               0
# Wind                              0
# Disturbance                       0
# Previously_Obs                    0
# Initial_Three_Min_Cnt             0
# dtype: int64

# %%
combined_df.drop(columns=['Sub_Unit_Code'], inplace=True)

# %%
combined_df.shape
# Out:
# (8531, 28)

# %%
combined_df['Distance'] = combined_df['Distance'].bfill

# %%
combined_df.isna().sum()
# Out:
# Admin_Unit_Code                 0
# Plot_Name                       0
# Location_Type                   0
# Year                            0
# Date                            0
# Start_Time                      0
# End_Time                        0
# Observer                        0
# Visit                           0
# Interval_Length                 0
# ID_Method                       1
# Distance                        0
# Flyover_Observed                0
# Sex                             0
# Common_Name                     0
# Scientific_Name                 0
# AcceptedTSN                    24
# TaxonCode                       2
# AOU_Code                        0
# PIF_Watchlist_Status            0
# Regional_Stewardship_Status     0
# Temperature                     0
# Humidity                        0
# Sky                             0
# Wind                            0
# Disturbance                     0
# Previously_Obs                  0
# Initial_Three_Min_Cnt           0
# dtype: int64

# %%
missing_id_method_rows = combined_df[combined_df['ID_Method'].isna()]

# %%
missing_id_method_rows
# Out:
#      Admin_Unit_Code  Plot_Name Location_Type  Year       Date Start_Time  \
# 1904            ANTI  ANTI-0140     Grassland  2018 2018-06-26   09:38:00
#
#       End_Time        Observer Visit Interval_Length  ... AOU_Code  \
# 1904  09:48:00  Kimberly Serno     2    7.5 - 10 min  ...     AMCR
#
#      PIF_Watchlist_Status Regional_Stewardship_Status Temperature   Humidity  \
# 1904                False                       False        29.6  50.299999
#
#                 Sky                                      Wind  \
# 1904  Partly Cloudy  Light breeze (4-7 mph) wind felt on face
#
#                  Disturbance Previously_Obs Initial_Three_Min_Cnt
# 1904  Slight effect on count          False                 False
#
# [1 rows x 28 columns]

# %%
combined_df['ID_Method'].value_counts()
# Out:
# ID_Method
# Singing          4433
# Visualization    2713
# Calling          1384
# Name: count, dtype: int64

# %%
combined_df['ID_Method'] = combined_df['ID_Method'].bfill()

# %%
combined_df.bfill(inplace=True)
# Out:
# C:\Users\Gowtham\AppData\Local\Temp\ipykernel_26228\3645281395.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   combined_df.bfill(inplace=True)

# %%
combined_df['ID_Method'].value_counts()
# Out:
# ID_Method
# Singing          4433
# Visualization    2713
# Calling          1385
# Name: count, dtype: int64

# %%
print(combined_df)
# Out:
#      Admin_Unit_Code  Plot_Name Location_Type  Year       Date Start_Time  \
# 0               ANTI  ANTI-0054     Grassland  2018 2018-05-22   05:35:00
# 1               ANTI  ANTI-0054     Grassland  2018 2018-05-22   05:35:00
# 2               ANTI  ANTI-0054     Grassland  2018 2018-05-22   05:35:00
# 3               ANTI  ANTI-0054     Grassland  2018 2018-05-22   05:35:00
# 4               ANTI  ANTI-0054     Grassland  2018 2018-05-22   05:35:00
# ...              ...        ...           ...   ...        ...        ...
# 8526            MONO  MONO-0089     Grassland  2018 2018-05-10   06:35:00
# 8527            MONO  MONO-0089     Grassland  2018 2018-05-10   06:35:00
# 8528            MONO  MONO-0089     Grassland  2018 2018-05-10   06:35:00
# 8529            MONO  MONO-0089     Grassland  2018 2018-05-10   06:35:00
# 8530            MONO  MONO-0089     Grassland  2018 2018-05-10   06:35:00
#
#       End_Time          Observer  Visit Interval_Length  ... AOU_Code  \
# 0     05:45:00  Elizabeth Oswald      1       0-2.5 min  ...     CHSP
# 1     05:45:00  Elizabeth Oswald      1    7.5 - 10 min  ...     EABL
# 2     05:45:00  Elizabeth Oswald      1       0-2.5 min  ...     GRSP
# 3     05:45:00  Elizabeth Oswald      1       0-2.5 min  ...     EABL
# 4     05:45:00  Elizabeth Oswald      1       0-2.5 min  ...     FISP
# ...        ...               ...    ...             ...  ...      ...
# 8526  06:46:00    Brian Swimelar      1     2.5 - 5 min  ...     EUST
# 8527  06:46:00    Brian Swimelar      1     2.5 - 5 min  ...     EUST
# 8528  06:46:00    Brian Swimelar      1     2.5 - 5 min  ...     EUST
# 8529  06:46:00    Brian Swimelar      1     2.5 - 5 min  ...     EUST
# 8530  06:46:00    Brian Swimelar      1     2.5 - 5 min  ...     EUST
#
#      PIF_Watchlist_Status  Regional_Stewardship_Status Temperature Humidity  \
# 0                   False                        False        20.0     79.0
# 1                   False                        False        20.0     79.0
# 2                   False                        False        20.0     79.0
# 3                   False                        False        20.0     79.0
# 4                   False                         True        20.0     79.0
# ...                   ...                          ...         ...      ...
# 8526                False                        False        19.0     63.0
# 8527                False                        False        19.0     63.0
# 8528                False                        False        19.0     63.0
# 8529                False                        False        19.0     63.0
# 8530                False                        False        19.0     63.0
#
#                   Sky                                       Wind  \
# 0     Cloudy/Overcast   Light breeze (4-7 mph) wind felt on face
# 1     Cloudy/Overcast   Light breeze (4-7 mph) wind felt on face
# 2     Cloudy/Overcast   Light breeze (4-7 mph) wind felt on face
# 3     Cloudy/Overcast   Light breeze (4-7 mph) wind felt on face
# 4     Cloudy/Overcast   Light breeze (4-7 mph) wind felt on face
# ...               ...                                        ...
# 8526    Partly Cloudy  Light air movement (1-3 mph) smoke drifts
# 8527    Partly Cloudy  Light air movement (1-3 mph) smoke drifts
# 8528    Partly Cloudy  Light air movement (1-3 mph) smoke drifts
# 8529    Partly Cloudy  Light air movement (1-3 mph) smoke drifts
# 8530    Partly Cloudy  Light air movement (1-3 mph) smoke drifts
#
#                  Disturbance Previously_Obs  Initial_Three_Min_Cnt
# 0     Slight effect on count          False                   True
# 1     Slight effect on count          False                  False
# 2     Slight effect on count          False                   True
# 3     Slight effect on count          False                   True
# 4     Slight effect on count          False                   True
# ...                      ...            ...                    ...
# 8526  Slight effect on count          False                  False
# 8527  Slight effect on count          False                  False
# 8528  Slight effect on count          False                  False
# 8529  Slight effect on count          False                  False
# 8530  Slight effect on count          False                  False
#
# [8531 rows x 28 columns]

# %%
combined_df.isna().sum()
# Out:
# Admin_Unit_Code                0
# Plot_Name                      0
# Location_Type                  0
# Year                           0
# Date                           0
# Start_Time                     0
# End_Time                       0
# Observer                       0
# Visit                          0
# Interval_Length                0
# ID_Method                      0
# Distance                       0
# Flyover_Observed               0
# Sex                            0
# Common_Name                    0
# Scientific_Name                0
# AcceptedTSN                    0
# TaxonCode                      0
# AOU_Code                       0
# PIF_Watchlist_Status           0
# Regional_Stewardship_Status    0
# Temperature                    0
# Humidity                       0
# Sky                            0
# Wind                           0
# Disturbance                    0
# Previously_Obs                 0
# Initial_Three_Min_Cnt          0
# dtype: int64

# %%
combined_df.drop_duplicates()
# Out:
#      Admin_Unit_Code  Plot_Name Location_Type  Year       Date Start_Time  \
# 0               ANTI  ANTI-0054     Grassland  2018 2018-05-22   05:35:00
# 1               ANTI  ANTI-0054     Grassland  2018 2018-05-22   05:35:00
# 2               ANTI  ANTI-0054     Grassland  2018 2018-05-22   05:35:00
# 3               ANTI  ANTI-0054     Grassland  2018 2018-05-22   05:35:00
# 4               ANTI  ANTI-0054     Grassland  2018 2018-05-22   05:35:00
# ...              ...        ...           ...   ...        ...        ...
# 8514            MONO  MONO-0089     Grassland  2018 2018-05-10   06:35:00
# 8515            MONO  MONO-0089     Grassland  2018 2018-05-10   06:35:00
# 8516            MONO  MONO-0089     Grassland  2018 2018-05-10   06:35:00
# 8517            MONO  MONO-0089     Grassland  2018 2018-05-10   06:35:00
# 8521            MONO  MONO-0089     Grassland  2018 2018-05-10   06:35:00
#
#       End_Time          Observer  Visit Interval_Length  ... AOU_Code  \
# 0     05:45:00  Elizabeth Oswald      1       0-2.5 min  ...     CHSP
# 1     05:45:00  Elizabeth Oswald      1    7.5 - 10 min  ...     EABL
# 2     05:45:00  Elizabeth Oswald      1       0-2.5 min  ...     GRSP
# 3     05:45:00  Elizabeth Oswald      1       0-2.5 min  ...     EABL
# 4     05:45:00  Elizabeth Oswald      1       0-2.5 min  ...     FISP
# ...        ...               ...    ...             ...  ...      ...
# 8514  06:46:00    Brian Swimelar      1       0-2.5 min  ...     AMRO
# 8515  06:46:00    Brian Swimelar      1     2.5 - 5 min  ...     COGR
# 8516  06:46:00    Brian Swimelar      1       0-2.5 min  ...     INBU
# 8517  06:46:00    Brian Swimelar      1       0-2.5 min  ...     EUST
# 8521  06:46:00    Brian Swimelar      1     2.5 - 5 min  ...     BLJA
#
#      PIF_Watchlist_Status  Regional_Stewardship_Status Temperature Humidity  \
# 0                   False                        False        20.0     79.0
# 1                   False                        False        20.0     79.0
# 2                   False                        False        20.0     79.0
# 3                   False                        False        20.0     79.0
# 4                   False                         True        20.0     79.0
# ...                   ...                          ...         ...      ...
# 8514                False                        False        19.0     63.0
# 8515                False                        False        19.0     63.0
# 8516                False                         True        19.0     63.0
# 8517                False                        False        19.0     63.0
# 8521                False                        False        19.0     63.0
#
#                   Sky                                       Wind  \
# 0     Cloudy/Overcast   Light breeze (4-7 mph) wind felt on face
# 1     Cloudy/Overcast   Light breeze (4-7 mph) wind felt on face
# 2     Cloudy/Overcast   Light breeze (4-7 mph) wind felt on face
# 3     Cloudy/Overcast   Light breeze (4-7 mph) wind felt on face
# 4     Cloudy/Overcast   Light breeze (4-7 mph) wind felt on face
# ...               ...                                        ...
# 8514    Partly Cloudy  Light air movement (1-3 mph) smoke drifts
# 8515    Partly Cloudy  Light air movement (1-3 mph) smoke drifts
# 8516    Partly Cloudy  Light air movement (1-3 mph) smoke drifts
# 8517    Partly Cloudy  Light air movement (1-3 mph) smoke drifts
# 8521    Partly Cloudy  Light air movement (1-3 mph) smoke drifts
#
#                  Disturbance Previously_Obs  Initial_Three_Min_Cnt
# 0     Slight effect on count          False                   True
# 1     Slight effect on count          False                  False
# 2     Slight effect on count          False                   True
# 3     Slight effect on count          False                   True
# 4     Slight effect on count          False                   True
# ...                      ...            ...                    ...
# 8514  Slight effect on count          False                   True
# 8515  Slight effect on count          False                  False
# 8516  Slight effect on count          False                   True
# 8517  Slight effect on count          False                   True
# 8521  Slight effect on count          False                   True
#
# [6571 rows x 28 columns]

# %%
combined_df.value_counts
# Out:
# <bound method DataFrame.value_counts of      Admin_Unit_Code  Plot_Name Location_Type  Year       Date Start_Time  \
# 0               ANTI  ANTI-0054     Grassland  2018 2018-05-22   05:35:00
# 1               ANTI  ANTI-0054     Grassland  2018 2018-05-22   05:35:00
# 2               ANTI  ANTI-0054     Grassland  2018 2018-05-22   05:35:00
# 3               ANTI  ANTI-0054     Grassland  2018 2018-05-22   05:35:00
# 4               ANTI  ANTI-0054     Grassland  2018 2018-05-22   05:35:00
# ...              ...        ...           ...   ...        ...        ...
# 8526            MONO  MONO-0089     Grassland  2018 2018-05-10   06:35:00
# 8527            MONO  MONO-0089     Grassland  2018 2018-05-10   06:35:00
# 8528            MONO  MONO-0089     Grassland  2018 2018-05-10   06:35:00
# 8529            MONO  MONO-0089     Grassland  2018 2018-05-10   06:35:00
# 8530            MONO  MONO-0089     Grassland  2018 2018-05-10   06:35:00
#
#       End_Time          Observer  Visit Interval_Length  ... AOU_Code  \
# 0     05:45:00  Elizabeth Oswald      1       0-2.5 min  ...     CHSP
# 1     05:45:00  Elizabeth Oswald      1    7.5 - 10 min  ...     EABL
# 2     05:45:00  Elizabeth Oswald      1       0-2.5 min  ...     GRSP
# 3     05:45:00  Elizabeth Oswald      1       0-2.5 min  ...     EABL
# 4     05:45:00  Elizabeth Oswald      1       0-2.5 min  ...     FISP
# ...        ...               ...    ...             ...  ...      ...
# 8526  06:46:00    Brian Swimelar      1     2.5 - 5 min  ...     EUST
# 8527  06:46:00    Brian Swimelar      1     2.5 - 5 min  ...     EUST
# 8528  06:46:00    Brian Swimelar      1     2.5 - 5 min  ...     EUST
# 8529  06:46:00    Brian Swimelar      1     2.5 - 5 min  ...     EUST
# 8530  06:46:00    Brian Swimelar      1     2.5 - 5 min  ...     EUST
#
#      PIF_Watchlist_Status  Regional_Stewardship_Status Temperature Humidity  \
# 0                   False                        False        20.0     79.0
# 1                   False                        False        20.0     79.0
# 2                   False                        False        20.0     79.0
# 3                   False                        False        20.0     79.0
# 4                   False                         True        20.0     79.0
# ...                   ...                          ...         ...      ...
# 8526                False                        False        19.0     63.0
# 8527                False                        False        19.0     63.0
# 8528                False                        False        19.0     63.0
# 8529                False                        False        19.0     63.0
# 8530                False                        False        19.0     63.0
#
#                   Sky                                       Wind  \
# 0     Cloudy/Overcast   Light breeze (4-7 mph) wind felt on face
# 1     Cloudy/Overcast   Light breeze (4-7 mph) wind felt on face
# 2     Cloudy/Overcast   Light breeze (4-7 mph) wind felt on face
# 3     Cloudy/Overcast   Light breeze (4-7 mph) wind felt on face
# 4     Cloudy/Overcast   Light breeze (4-7 mph) wind felt on face
# ...               ...                                        ...
# 8526    Partly Cloudy  Light air movement (1-3 mph) smoke drifts
# 8527    Partly Cloudy  Light air movement (1-3 mph) smoke drifts
# 8528    Partly Cloudy  Light air movement (1-3 mph) smoke drifts
# 8529    Partly Cloudy  Light air movement (1-3 mph) smoke drifts
# 8530    Partly Cloudy  Light air movement (1-3 mph) smoke drifts
#
#                  Disturbance Previously_Obs  Initial_Three_Min_Cnt
# 0     Slight effect on count          False                   True
# 1     Slight effect on count          False                  False
# 2     Slight effect on count          False                   True
# 3     Slight effect on count          False                   True
# 4     Slight effect on count          False                   True
# ...                      ...            ...                    ...
# 8526  Slight effect on count          False                  False
# 8527  Slight effect on count          False                  False
# 8528  Slight effect on count          False                  False
# 8529  Slight effect on count          False                  False
# 8530  Slight effect on count          False                  False
#
# [8531 rows x 28 columns]>

# %%
combined_df.isna().sum()
# Out:
# Admin_Unit_Code                0
# Plot_Name                      0
# Location_Type                  0
# Year                           0
# Date                           0
# Start_Time                     0
# End_Time                       0
# Observer                       0
# Visit                          0
# Interval_Length                0
# ID_Method                      0
# Distance                       0
# Flyover_Observed               0
# Sex                            0
# Common_Name                    0
# Scientific_Name                0
# AcceptedTSN                    0
# TaxonCode                      0
# AOU_Code                       0
# PIF_Watchlist_Status           0
# Regional_Stewardship_Status    0
# Temperature                    0
# Humidity                       0
# Sky                            0
# Wind                           0
# Disturbance                    0
# Previously_Obs                 0
# Initial_Three_Min_Cnt          0
# dtype: int64

# %%
combined_df["Humidity"]=combined_df["Humidity"].round(0).astype(int)

# %%
combined_df["Temperature"]=combined_df["Temperature"].round(0).astype(int)

# %%
combined_df.to_csv("GrassLand.csv",index=False)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(x="ID_Method",data=combined_df)
# Out:
# <Axes: xlabel='ID_Method', ylabel='count'>

# %%
#Common_Name
plt.figure(figsize=(20,5))
sns.countplot(x="Common_Name",data=combined_df)
plt.xticks(rotation=90)
plt.show()

# %%
#Observer
sns.countplot(x="Observer",data=combined_df)
# Out:
# <Axes: xlabel='Observer', ylabel='count'>
